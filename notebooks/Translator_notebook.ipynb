# %% [markdown]
# ## Translator Tool Test-Notebook Ver.

# %%
import pickle

# %%
with open("../data/predicter/predicter_1.pkl", 'rb') as f:
    predicter = pickle.load(f)

# %%
predicter.translate_snt("I was there, always.")
# Out:
# 'Byłem tam, zawsze.'

# %%
with open("../data/tokenizer_encoder/tokenizer_pol_1.pkl", 'rb') as f:
    tokenizer_pol = pickle.load(f)

with open("../data/tokenizer_encoder/tokenizer_eng_1.pkl", 'rb') as f:
    tokenizer_eng = pickle.load(f)

# %%
with open("../data/tokenizer_encoder/encoder_pol_1.pkl", 'rb') as f:
    encoder_pol = pickle.load(f)

with open("../data/tokenizer_encoder/encoder_eng_1.pkl", 'rb') as f:
    encoder_eng = pickle.load(f)
